# %%
import numpy as np
from svgis import *
from IPython.display import display, HTML
from tools.data import *
from tools.geodata import *

# %%
#geo = svgis.SVGIS(FILENAME_PATTERN % DATA_FILES["bm-shape"]["filename"])
#geo.compose()

# %%
from shapely.geometry import Polygon, MultiPolygon

class GeoDataTest:
    
    def __init__(self, fileid):
        from tools.data import load_json
        self.data = load_json(fileid)

        self.polygons = {}
        for i, f in enumerate(self.data["features"]):
            #points = self._get_points(i)
            poly = self._get_polygon(i)
            if poly:
                self.polygons[f["n"]] = {
                    "polygon": poly,
                    "area": poly.area,
                }

    def _get_points(self, feature_idx):
        # b, d, e, c
        bb = [float(x) for x in self.data["boundingBox"].split()]
        off_x, off_y = bb[:2]
        width, height = bb[2]-bb[0], bb[3]-bb[1]
        pix_w, pix_h = self.data["pixelWidth"], self.data["pixelHeight"]
        points = self.data["features"][feature_idx]["p"][0]
        xa, ya = 0, 0
        ret = []
        for i in range(0, len(points), 2):
            xa += points[i]
            ya += points[i+1]
            ret.append((
                off_x + xa / pix_w * width,
                off_y + ya / pix_h * height
            ))
        return ret

    def _get_polygon(self, feature_idx):
        points = self._get_points(feature_idx)
        if len(points) < 3:
            return None
        return Polygon(points)

    def _get_polygons(self):
        polygons = []
        for i in range(len(self.data["features"])):
            poly = self._get_polygon(i)
            if poly:
                polygons.append(poly)
        return MultiPolygon(polygons)
    
    def polygon_list(self):
        polygons = []
        for n in sorted(self.polygons):
            poly = self.polygons[n].copy()
            poly["id"] = n
            polygons.append(poly)
        return polygons
            
    def to_svg(self, color=None, heatmap=None):
        polygons = self.polygon_list()

        bb = MultiPolygon(p["polygon"] for p in polygons).bounds
        bb = (bb[0], bb[1], bb[2]-bb[0], bb[3]-bb[1])
        svg = """<svg width="400px" height="400px" viewBox="%s" xmlns="http://www.w3.org/2000/svg" version="1.1">""" % (
            " ".join("%s" % x for x in bb),
        )
        
        if heatmap is not None:
            color = dict()
            for poly in polygons:
                color[poly["id"]] = heatmap.get(poly["id"], 0)
            ma = max(color.values())
            if ma:
                color = {k: color[k] / ma for k in color}
            for k in color:
                v = color[k]
                rgb = (v*255, math.pow(v, .3)*255, math.sin(v*3.14)*255)
                color[k] = "rgb(%s, %s, %s)" % tuple((max(0, min(255, x)) for x in rgb))
            
        for poly in polygons:
            svgpoints = " ".join("%s,%s" % (round(t[0]), round(bb[1]+bb[3]-(t[1] - bb[1])))
                                 for t in poly["polygon"].exterior.coords)
            if color is None:
                col = '#ddd'
            elif callable(color):
                col = color(poly["id"])
            elif isinstance(color, dict):
                col = color.get(poly["id"], "#ddd")
            else:
                col = color                
            svg += '<polygon fill="%s" stroke="black" stroke-width="10" points="%s" />' % (
                col, svgpoints
            )

        svg += '</svg>'
        return svg

    def display(self, **kwargs):
        from IPython.display import display, HTML
        display(HTML(self.to_svg(**kwargs)))        

geo = GeoDataTest("bm-shape")
#print(geo.features)
#print([geo.features[f]["area"] for f in geo.features])
geo.display(heatmap={"1": 1, "83": 2})
# Out:
827 682297,5642824 682301,5642822 682303,5642821 682305,5642820 682309,5642829 682306,5642835 682303,5642840 682318,5642849 682291,5642892 682299,5642933 682306,5642967 682315,5643007 682334,5643083 682359,5643119 682384,5643137 682396,5643168 682403,5643186 682402,5643195 682411,5643210 682424,5643244 682430,5643265 682431,5643278 682431,5643319 682432,5643361 682433,5643368 682435,5643420 682435,5643436 682436,5643447 682436,5643472 682435,5643494 682434,5643498 682432,5643516 682435,5643526 682426,5643549 682423,5643557 682419,5643568 682418,5643570 682416,5643581 682418,5643587 682419,5643588 682417,5643604 682413,5643633 682409,5643662 682406,5643680 682399,5643705 682390,5643726 682371,5643754 682364,5643763 682348,5643780 682311,5643815 682278,5643841 682245,5643860 682230,5643867 682175,5643783 682158,5643755 682154,5643744 682150,5643726 682149,5643707 682134,5643683 682119,5643664 682106,5643651 682098,5643640 682086,5643616 682078,5643607 682073,5643604 682063,5643604 682043,5643606 682039,5643618 682038,5643658 682036,5643697 682035,5643712 682034,5643721 682027,5643720 682018,5643719 682017,5643736 682017,5643736 682019,5643736 682020,5643737 682021,5643738 682022,5643739 682022,5643740 682022,5643741 682022,5643742 682022,5643743 682022,5643744 682022,5643745 682021,5643746 682020,5643747 682019,5643747 682018,5643748 682017,5643748 682016,5643748 682015,5643748 682012,5643748 682009,5643748 682009,5643748 682007,5643745 681995,5643745 681980,5643746 681962,5643749 681949,5643749 681950,5643718 681950,5643698 681949,5643688 681948,5643673 681948,5643653 681948,5643642 681950,5643633 681949,5643602 681948,5643586 681949,5643566 681911,5643563 681893,5643560 681821, ...

# %%
def get_bmwahl_by_stats(bm):
    geo = GeoData("bm-shape")
    geo2 = GeoData("stats-shape")
    
    bm_poly_map = {str(int(k.split()[0])):bm.loc[k] for k in bm.index}
    
    #df = pd.DataFrame(columns=bm.columns, index="Bezirk")
    skey_sum_dic = dict()
    for wkey in geo.polygons:
        wpoly = geo.polygons[wkey]
        row = bm_poly_map[wkey]
        for skey in geo2.polygons:
            spoly = geo2.polygons[skey]
            if spoly["polygon"].intersects(wpoly["polygon"]):
                try:
                    intersection = spoly["polygon"].intersection(wpoly["polygon"])
                    shared_area = intersection.area
                except:
                    shared_area = 0
                if skey not in skey_sum_dic:
                    skey_sum_dic[skey] = [0] * bm.shape[0]
                sums = skey_sum_dic[skey]
                fac = shared_area / wpoly["area"]
                for i, val in enumerate(row):
                    sums[i] += int(round(val * fac))
    
    df = pd.DataFrame({bm.columns[x]: [skey_sum_dic[skey][x] for y, skey in enumerate(sorted(skey_sum_dic))]
                       for x in range(len(bm.columns))},
                      index=sorted(skey_sum_dic), columns=bm.columns)
    return df

bm1 = load_pandas_bmwahl("bm01")
bm1 = rename_bmwahl(bm1)
bm1 = bm1[bm1["n"] != 0]
bms1 = get_bmwahl_by_stats(bm1)
bms1
# Out:
# TopologyException: Input geom 1 is invalid: Self-intersection at or near point 684562.64983339992 5639994.1659012409 at 684562.64983339992 5639994.1659012409
# TopologyException: Input geom 1 is invalid: Self-intersection at or near point 684562.64983339992 5639994.1659012409 at 684562.64983339992 5639994.1659012409
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point 680635.68085010001 5643501.030052728 at 680635.68085010001 5643501.030052728
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point 680635.68085010001 5643501.030052728 at 680635.68085010001 5643501.030052728
# TopologyException: Input geom 1 is invalid: Self-intersection at or near point 680960.20962908445 5641403.6809530165 at 680960.20962908445 5641403.6809530165
# TopologyException: Input geom 1 is invalid: Self-intersection at or near point 680960.20962908445 5641403.6809530165 at 680960.20962908445 5641403.6809530165
# TopologyException: Input geom 1 is invalid: Self-intersection at or near point 684851.7919808916 5639939.970836482 at 684851.7919808916 5639939.970836482
# TopologyException: Input geom 1 is invalid: Self-intersection at or near point 684851.7919808916 5639939.970836482 at 684851.7919808916 5639939.970836482
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point 680635.68085010001 5643501.030052728 at 680635.68085010001 5643501.030052728
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point 680635.68085010001 5643501.030052728 at 680635.68085010001 5643501.030052728
#                                    n    nw  nu    ng  CDU  LINKE  SPD  AFD  \
# Ammerbach Ort                    368   181   0   181   27     11   54   21
# Beutenberg / Winzerlaer Straße  2234   913   3   910  134     95  212   74
# Burgau Ort                       348   170   1   169   28      8   43   24
# Closewitz                        112    76   0    76   34      0    8    8
# Cospeda                         1128   580   2   578   83     46  144   45
# Drackendorf                      676   382   1   381   64     26   89   43
# Drackendorf / Lobeda-Ost        2570   998  10   988  152    175  193  103
# Göschwitz                        499   255   5   250   40     21   56   29
# Ilmnitz                          412   210   1   209   48      7   53   22
# Isserstedt                       679   333   3   330   65     27   70   30
# Jena-Nord                       8488  3494  17  3477  437    418  896  213
# Jena-Süd                        6764  3110  17  3093  389    334  871  140
# Jena-West                       7094  3263  12  3251  382    383  838  147
# Jena-Zentrum                    3818  1552   9  1544  209    220  458   63
# Jenaprießnitz                    753   403   1   402   83     28   85   31
# Krippendorf                       96    58   0    58    4      2   23   14
# Kunitz                           526   307   1   305   39     16   68   37
# Laasan                           182   106   1   106   13      5   23   13
# Leutra                           115    80   1    79   16      3   36    4
# Lichtenhain Ort                    1     0   0     0    0      0    0    0
# Lobeda-Altstadt                 1566   778   7   772  132     77  188   74
# Lobeda-Ost                      4284  1415  10  1405  224    223  324  167
# Lobeda-West                     7606  2350  21  2329  333    397  552  308
# Löbstedt Ort                     385   155   2   153   17     11   23   17
# Lützeroda                        140    84   1    83   21     14   22    6
# Maua                             307   189   1   188   37     23   27   30
# Mühlenstraße                       1     0   0     0    0      0    0    0
# Münchenroda                      235   121   0   121   17      6   16   19
# Nord II                         5320  2375  21  2354  329    268  554  215
# Remderoda                         66    34   0    34    5      2    5    5
# Ringwiese Flur Burgau            843   439   2   437   64     37   88   33
# Vierzehnheiligen                  88    52   0    52   15      3    6    3
# Wenigenjena / Kernberge         2003  1057   1  1056  141     76  300   44
# Wenigenjena / Schlegelsberg     4872  2418   9  2409  321    234  553  201
# Wenigenjena Ort                 3735  1762   0  1762  214    178  425  109
# Winzerla                        7923  2759  16  2742  363    334  648  318
# Wogau                            218   117   0   116   24      8   25    9
# Wöllnitz                         508   268   0   268   42     12   60   29
# Ziegenhain Ort                   318   167   1   166   37      7   53   13
# Ziegenhainer Tal                1817   925   3   922  129     84  210   63
# Zwätzen                         2403  1217   4  1213  158     99  244   76
#
#                                 GRÜNE  FDP  πRATEN  SANDRO  ARNE
# Ammerbach Ort                       6   54       7       0     0
# Beutenberg / Winzerlaer Straße     60  278      39      12     7
# Burgau Ort                          9   41      10       4     1
# Closewitz                           3   19       4       0     0
# Cospeda                            26  196      29       7     2
# Drackendorf                        12  139       5       2     1
# Drackendorf / Lobeda-Ost           30  242      33      33    27
# Göschwitz                           8   74      13       8     1
# Ilmnitz                             4   71       1       3     0
# Isserstedt                         20   97       8      10     3
# Jena-Nord                         386  856     181      45    44
# Jena-Süd                          374  720     183      46    34
# Jena-West                         429  802     190      41    44
# Jena-Zentrum                      203  248     108      22    10
# Jenaprießnitz                      11  140      14       7     4
# Krippendorf                         0    9       3       3     0
# Kunitz                              8  113      13       7     6
# Laasan                              3   39       4       2     2
# Leutra                              3   12       0       3     2
# Lichtenhain Ort                     0    0       0       0     0
# Lobeda-Altstadt                    43  212      21      14     9
# Lobeda-Ost                         64  291      44      40    30
# Lobeda-West                       108  452      76      78    23
# Löbstedt Ort                        8   61      10       3     2
# Lützeroda                           5   14       1       0     0
# Maua                                0   29       3      35     4
# Mühlenstraße                        0    0       0       0     0
# Münchenroda                         6   50       1       5     0
# Nord II                           124  692      90      38    45
# Remderoda                           2   14       0       1     0
# Ringwiese Flur Burgau              16  145      26      20     8
# Vierzehnheiligen                    2   19       1       3     0
# Wenigenjena / Kernberge           101  333      45       8     7
# Wenigenjena / Schlegelsberg       153  773     107      37    29
# Wenigenjena Ort                   157  541      83      33    23
# Winzerla                          171  657      96     111    43
# Wogau                               3   40       4       2     1
# Wöllnitz                           17   83      14       4     8
# Ziegenhain Ort                     18   35       4       0     0
# Ziegenhainer Tal                   54  299      41      19    21
# Zwätzen                            52  464      91      13    16

# %%
bms1.sum()
# Out:
# n         81501
# nw        35153
# nu          184
# ng        34969
# CDU        4870
# LINKE      3918
# SPD        8543
# AFD        2800
# GRÜNE      2699
# FDP        9354
# πRATEN     1603
# SANDRO      719
# ARNE        457
# dtype: int64

# %%
bm1 = load_pandas_bmwahl("bm01")
bm1 = rename_bmwahl(bm1)
bm1 = bm1[bm1["n"] != 0]
geo = GeoDataTest("bm-shape")

# %%
area_dict = {int(k): geo.polygons[k]["area"] for k in geo.polygons}
areas = pd.Series([area_dict.get(int(k.split()[0]), -1) for k in bm1.index], index=bm1.index)
dens = bm1["n"] / areas 
dens /= max(dens)
#print(dens)
geo.display(heatmap={str(int(k.split()[0])): dens[k] for k in dens.index})
# Out:
5643604 682043,5643606 682039,5643618 682038,5643658 682036,5643697 682035,5643712 682034,5643721 682027,5643720 682018,5643719 682017,5643736 682017,5643736 682019,5643736 682020,5643737 682021,5643738 682022,5643739 682022,5643740 682022,5643741 682022,5643742 682022,5643743 682022,5643744 682022,5643745 682021,5643746 682020,5643747 682019,5643747 682018,5643748 682017,5643748 682016,5643748 682015,5643748 682012,5643748 682009,5643748 682009,5643748 682007,5643745 681995,5643745 681980,5643746 681962,5643749 681949,5643749 681950,5643718 681950,5643698 681949,5643688 681948,5643673 681948,5643653 681948,5643642 681950,5643633 681949,5643602 681948,5643586 681949,5643566 681911,5643563 681893,5643560  ...

# %%
def load_pandas_stat(year=None):
    if year is not None:
        year = str(year)

    data = load_json("stats-index")

    geographies = data["geographies"][0]
    dic = OrderedDict({
        "Bezirk": [f["name"] for f in geographies["features"]],
    })

    for theme in geographies["themes"]:
        url_part = theme["fileName"].split("/")[-1]
        fileid = "stat-%(themeId)s" % theme
        DATA_FILES[fileid] = {
            "filename": "%s.json" % fileid,
            "url": "http://statistiken.jena.de/instantatlas/stadtbezirksstatistik/%s" % url_part
        }
        data = load_json(fileid)
        for indicator in data["indicators"]:
            if year is not None and indicator["date"] != year:
                continue
            dic[("%(name)s(%(date)s)" % indicator).strip()] = [int(x) for x in indicator["values"]]

    df = pd.DataFrame(dic)
    df.index = [x.strip() for x in df["Bezirk"]]
    del df["Bezirk"]
    return df

stats = load_pandas_stat(2016)
stats = stats[stats.index != "nicht zugeordnet"]
#stats.drop()
#print(stats.columns)
geo2 = GeoDataTest("stats-shape")
s = stats["Arbeitslose insgesamt(2016)"].to_dict()
s = {k: int(s[k]) for k in s}
geo2.display(heatmap=s)
stats.sum()
# Out:
# <svg width="400px" height="400px" viewBox="675504.8727655 5636950.498494976 12254.084468999994 14760.603010047227" xmlns="http://www.w3.org/2000/svg" version="1.1"><polygon fill="rgb(1.7677642980935875, 57.38593127482604, 5.550341546913504)" stroke="black" stroke-width="10" points="679617,5646661 679590,5646715 679619,5646738 679596,5646759 679584,5646785 679556,5646847 679525,5646901 679506,5646981 679505,5647006 679503,5647044 679507,5647121 679507,5647152 679507,5647234 679509,5647235 679479,5647252 679457,5647276 679455,5647278 679453,5647281 679449,5647285 679433,5647268 679421,5647257 679398,5647284 679370,5647316 679367,5647320 679352,5647305 679350,5647301 679332,5647283 679327,5647293 679321,5647320 679316,5647322 679312,5647323 679304,5647328 679269,5647303 679244,5647287 679242,5647284 679239,5647283 679238,5647281 679235,5647280 679232,5647280 679228,5647278 679208,5647272 679181,5647264 679180,5647262 679176,5647265 679172,5647266 679138,5647280 679112,5647297 679098,5647307 679057,5647332 679000,5647366 678992,5647371 678980,5647380 678968,5647386 678961,5647385 678941,5647377 678913,5647366 678879,5647353 678845,5647340 678844,5647339 678841,5647339 678821,5647331 678801,5647323 678725,5647346 678712,5647345 678704,5647342 678694,5647340 678684,5647338 678678,5647336 678646,5647331 678654,5647308 678667,5647274 678655
# Räume in Wohnungen mit 7 und mehr Räumen(2016)                                   19646
# Wohnfläche(2016)                                                               4129984
# Length: 164, dtype: int64

# %%
def calc_stats_percent(stats):
    key = "Einwohner (Hauptwohnung) insgesamt(2016)"
    df = stats.copy()
    # Stimmen für Parteien in Prozent der gültigen Stimmen
    for col in stats.columns:
        if col != key:
            df[col] = df[col] / df[key] * 100
    return df

def get_stats_correlations(stats, bms):
    dic = OrderedDict()
    for wkey in bms.columns: 
        #s = set(stats.index) - set(bms1[wkey].index)
        #print(len(stats.index))
        #print(stats.columns)

        dic[wkey] = [np.corrcoef(stats[skey], bms[wkey])[0][1] 
                     for skey in stats.columns]
    df = pd.DataFrame(dic, index=stats.columns)
    df.apply(lambda s: s.apply(lambda v: int(v*100) if abs(v)>=.80 else ""))
    return df

#calc_percent(bms1)
df = get_stats_correlations(
    calc_stats_percent(stats),
    calc_bmwahl_percent(bms1),
)
df.apply(lambda s: s.apply(lambda v: int(v*100) if abs(v)>=.50 else ""))
#stats["Arbeitslose insgesamt(2016)"] /= stats["Einwohner (Hauptwohnung) insgesamt(2016)"]
#calc_stats_percent(stats)
#calc_bmwahl_percent(bms1)
#print(bms1["n"])
#print(stats["Einwohner (Hauptwohnung) insgesamt(2016)"])
#np.corrcoef(stats["Einwohner (Hauptwohnung) insgesamt(2016)"], bms1["n"])
# Out:
# /home/bergi/prog/python/wahl/env/lib/python3.5/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/bergi/prog/python/wahl/env/lib/python3.5/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
#                                                       n   nw nu   ng  CDU  \
# Arbeitslose insgesamt(2016)                              -50
# Arbeitslose - Männer(2016)
# Arbeitslose - Frauen(2016)                           61  -55
# Arbeitslose - Deutsche(2016)
# Arbeitslose - Ausländer(2016)                        50
# Arbeitslose - unter 20 Jahre alt(2016)               62
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)
# Arbeitslose - 55 Jahre und älter(2016)
# SGB II - Arbeitslose insgesamt(2016)
# SGB II - Arbeitslose - Männer(2016)
# SGB II - Arbeitslose - Frauen(2016)                  61  -55
# SGB II - Arbeitslose - Deutsche(2016)
# SGB II - Arbeitslose - Ausländer(2016)               50
# SGB II - Arbeitslose - unter 20 Jahre alt(2016)      57
# SGB II - Arbeitslose - 20 bis unter 25 Jahre al...
# SGB II - Arbeitslose - 55 Jahre und älter(2016)      53  -54
# SGB III - Arbeitslose insgesamt(2016)
# SGB III - Arbeitslose - Männer(2016)
# SGB III - Arbeitslose - Frauen(2016)
# SGB III - Arbeitslose - Deutsche(2016)
# SGB III - Arbeitslose - Ausländer(2016)              56
# SGB III - Arbeitslose - unter 20 Jahre alt(2016)
# SGB III - Arbeitslose - 20 bis unter 25 Jahre a...
# SGB III - Arbeitslose - 55 Jahre und älter(2016)
# Einwohner (Hauptwohnung) insgesamt(2016)             86
# Einwohner (HW) männlich(2016)
# Einwohner (HW) weiblich(2016)
# Einwohner (HW) - Deutsche(2016)                           70      52
# SGB III - Arbeitslose - unter 20 Jahre alt(2016)
# SGB III - Arbeitslose - 20 bis unter 25 Jahre a...
# SGB III - Arbeitslose - 55 Jahre und älter(2016)
# Einwohner (Hauptwohnung) insgesamt(2016)
# Einwohner (HW) männlich(2016)
# Einwohner (HW) weiblich(2016)
# Einwohner (HW) - Deutsche(2016)
# Einwohner (HW) - Deutsche, männlich(2016)
# Einwohner (HW) - Deutsche, weiblich(2016)
# ...                                                   ...    ...  ...
# Sozialversicherungspflichtig Beschäftigte - unt...
# Sozialversicherungspflichtig Beschäftigte - 20 ...
# Wohnberechtigte Bevölkerung (HW und NW) insgesa...
# Wohnberechtigte Bevölkerung männlich(2016)
# Wohnberechtigte Bevölkerung weiblich(2016)
# Wohnberechtigte Bevölkerung - Deutsche(2016)
# Wohnberechtigte Bevölkerung - Ausländer(2016)
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 6 bis 10 Wohnungen(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohnungen insgesamt(2016)
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)
# Wohnungen mit 4 Räumen(2016)
# Wohnungen mit 5 Räumen(2016)
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# Räume in Wohnungen mit 7 und mehr Räumen(2016)
# Wohnfläche(2016)
#
# [164 rows x 13 columns]

# %%
(stats.add(bms1,fill_value=0)).corr().apply(lambda s: s.apply(lambda v: int(v*100) if abs(v)>=.80 else ""))
# Out:
#                                                     AFD ARNE Ackerland(2016)  \
# AFD                                                 100   87
# ARNE                                                 87  100
# Ackerland(2016)                                                          100
# Alleinerziehende Frauen mit 1 Kind(2016)             94   89
# Alleinerziehende Frauen mit 2 Kindern(2016)          93   85
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...   82
# Alleinerziehende Männer mit 1 Kind(2016)             95   88
# Alleinerziehende Männer mit 2 Kindern(2016)          82   87
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)        86
# Arbeitslose - 55 Jahre und älter(2016)               88
# Arbeitslose - Ausländer(2016)
# Arbeitslose - Deutsche(2016)                         91   82
# Arbeitslose - Frauen(2016)                           90
# Arbeitslose - Männer(2016)                           89
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)                          90
# Betriebsfläche(2016)
# CDU                                                  90   93
# Einpersonenhaushalte(2016)                           85   87
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...   83   88
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)        96   85
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)                 83   85
# Einpersonenhaushalte, weiblich(2016)                 88   89
# Einwohner (HW) - Ausländer(2016)
# Einwohner (HW) - Ausländer, männlich(2016)
# Einwohner (HW) - Ausländer, weiblich(2016)
# Einwohner (HW) - Deutsche(2016)                      91   93
# Einwohner (HW) - Deutsche, männlich(2016)            90   93
# ...                                                 ...  ...             ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...   88   89
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...        81
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...   84   91
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...   92   90
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...   97   89
# Wohnberechtigte Bevölkerung männlich(2016)           90   90
# Wohnberechtigte Bevölkerung weiblich(2016)           91   91
# Wohnfläche(2016)                                     90   92
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)                86
# Wohngebäude mit 6 bis 10 Wohnungen(2016)             80   89
# Wohnungen insgesamt(2016)                            92   91
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)                         81
# Wohnungen mit 3 Räumen(2016)                         82   89
# Wohnungen mit 4 Räumen(2016)                         94   87
# Wohnungen mit 5 Räumen(2016)                         93   88
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n                                                    93   92
# ng                                                   87   93
# nu                                                   89   86
# nw                                                   87   93
# sonstige Fläche(2016)
# πRATEN                                                    85
#
#                                                    Alleinerziehende Frauen mit 1 Kind(2016)  \
# AFD                                                                                      94
# ARNE                                                                                     89
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)                                                100
# Alleinerziehende Frauen mit 2 Kindern(2016)                                              96
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...                                       82
# Alleinerziehende Männer mit 1 Kind(2016)                                                 96
# Alleinerziehende Männer mit 2 Kindern(2016)                                              82
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)                                            91
# Arbeitslose - 55 Jahre und älter(2016)                                                   89
# Arbeitslose - Ausländer(2016)                                                            80
# Arbeitslose - Deutsche(2016)                                                             96
# Arbeitslose - Frauen(2016)                                                               93
# Arbeitslose - Männer(2016)                                                               95
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)                                                              94
# Betriebsfläche(2016)
# CDU                                                                                      89
# Einpersonenhaushalte(2016)                                                               93
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...                                       92
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)                                            96
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)                                                     91
# Einpersonenhaushalte, weiblich(2016)                                                     95
# Einwohner (HW) - Ausländer(2016)                                                         81
# Einwohner (HW) - Ausländer, männlich(2016)                                               80
# Einwohner (HW) - Ausländer, weiblich(2016)                                               81
# Einwohner (HW) - Deutsche(2016)                                                          95
# Einwohner (HW) - Deutsche, männlich(2016)                                                95
# ...                                                                                     ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...                                       92
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...                                       88
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...                                       90
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...                                       95
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...                                       95
# Wohnberechtigte Bevölkerung männlich(2016)                                               95
# Wohnberechtigte Bevölkerung weiblich(2016)                                               96
# Wohnfläche(2016)                                                                         95
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)                                               82
# Wohngebäude mit 6 bis 10 Wohnungen(2016)                                                 86
# Wohnungen insgesamt(2016)                                                                97
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)                                                             87
# Wohnungen mit 3 Räumen(2016)                                                             86
# Wohnungen mit 4 Räumen(2016)                                                             98
# Wohnungen mit 5 Räumen(2016)                                                             94
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n                                                                                        94
# ng                                                                                       88
# nu                                                                                       86
# nw                                                                                       88
# sonstige Fläche(2016)
# πRATEN
#
#                                                    Alleinerziehende Frauen mit 2 Kindern(2016)  \
# AFD                                                                                         93
# ARNE                                                                                        85
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)                                                    96
# Alleinerziehende Frauen mit 2 Kindern(2016)                                                100
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...                                          86
# Alleinerziehende Männer mit 1 Kind(2016)                                                    92
# Alleinerziehende Männer mit 2 Kindern(2016)                                                 80
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)                                               90
# Arbeitslose - 55 Jahre und älter(2016)                                                      90
# Arbeitslose - Ausländer(2016)                                                               84
# Arbeitslose - Deutsche(2016)                                                                93
# Arbeitslose - Frauen(2016)                                                                  94
# Arbeitslose - Männer(2016)                                                                  92
# Arbeitslose - unter 20 Jahre alt(2016)                                                      83
# Arbeitslose insgesamt(2016)                                                                 94
# Betriebsfläche(2016)
# CDU                                                                                         89
# Einpersonenhaushalte(2016)                                                                  92
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...                                          88
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)                                               94
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)                                                        90
# Einpersonenhaushalte, weiblich(2016)                                                        93
# Einwohner (HW) - Ausländer(2016)                                                            88
# Einwohner (HW) - Ausländer, männlich(2016)                                                  87
# Einwohner (HW) - Ausländer, weiblich(2016)                                                  89
# Einwohner (HW) - Deutsche(2016)                                                             93
# Einwohner (HW) - Deutsche, männlich(2016)                                                   93
# ...                                                                                        ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...                                          92
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...                                          89
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...                                          88
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...                                          90
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...                                          94
# Wohnberechtigte Bevölkerung männlich(2016)                                                  95
# Wohnberechtigte Bevölkerung weiblich(2016)                                                  95
# Wohnfläche(2016)                                                                            93
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)
# Wohngebäude mit 6 bis 10 Wohnungen(2016)                                                    85
# Wohnungen insgesamt(2016)                                                                   95
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)                                                                84
# Wohnungen mit 3 Räumen(2016)                                                                83
# Wohnungen mit 4 Räumen(2016)                                                                97
# Wohnungen mit 5 Räumen(2016)                                                                94
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n                                                                                           93
# ng                                                                                          87
# nu                                                                                          90
# nw                                                                                          87
# sonstige Fläche(2016)
# πRATEN
#
#                                                    Alleinerziehende Frauen mit 3 oder mehr  Kindern(2016)  \
# AFD                                                                                                82
# ARNE
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)                                                           82
# Alleinerziehende Frauen mit 2 Kindern(2016)                                                        86
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...                                                100
# Alleinerziehende Männer mit 1 Kind(2016)                                                           82
# Alleinerziehende Männer mit 2 Kindern(2016)
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)                                                      90
# Arbeitslose - 55 Jahre und älter(2016)                                                             87
# Arbeitslose - Ausländer(2016)                                                                      95
# Arbeitslose - Deutsche(2016)                                                                       85
# Arbeitslose - Frauen(2016)                                                                         92
# Arbeitslose - Männer(2016)                                                                         88
# Arbeitslose - unter 20 Jahre alt(2016)                                                             88
# Arbeitslose insgesamt(2016)                                                                        91
# Betriebsfläche(2016)
# CDU
# Einpersonenhaushalte(2016)
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)                                                      80
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)
# Einpersonenhaushalte, weiblich(2016)
# Einwohner (HW) - Ausländer(2016)                                                                   90
# Einwohner (HW) - Ausländer, männlich(2016)                                                         90
# Einwohner (HW) - Ausländer, weiblich(2016)                                                         90
# Einwohner (HW) - Deutsche(2016)
# Einwohner (HW) - Deutsche, männlich(2016)
# ...                                                                                               ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...
# Wohnberechtigte Bevölkerung männlich(2016)
# Wohnberechtigte Bevölkerung weiblich(2016)
# Wohnfläche(2016)
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)                                                        82
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)
# Wohngebäude mit 6 bis 10 Wohnungen(2016)
# Wohnungen insgesamt(2016)
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)
# Wohnungen mit 4 Räumen(2016)                                                                       85
# Wohnungen mit 5 Räumen(2016)                                                                       82
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n
# ng
# nu
# nw
# sonstige Fläche(2016)
# πRATEN
#
#                                                    Alleinerziehende Männer mit 1 Kind(2016)  \
# AFD                                                                                      95
# ARNE                                                                                     88
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)                                                 96
# Alleinerziehende Frauen mit 2 Kindern(2016)                                              92
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...                                       82
# Alleinerziehende Männer mit 1 Kind(2016)                                                100
# Alleinerziehende Männer mit 2 Kindern(2016)
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)                                            88
# Arbeitslose - 55 Jahre und älter(2016)                                                   87
# Arbeitslose - Ausländer(2016)
# Arbeitslose - Deutsche(2016)                                                             94
# Arbeitslose - Frauen(2016)                                                               89
# Arbeitslose - Männer(2016)                                                               92
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)                                                              91
# Betriebsfläche(2016)
# CDU                                                                                      90
# Einpersonenhaushalte(2016)                                                               91
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...                                       91
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)                                            93
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)                                                     90
# Einpersonenhaushalte, weiblich(2016)                                                     93
# Einwohner (HW) - Ausländer(2016)
# Einwohner (HW) - Ausländer, männlich(2016)
# Einwohner (HW) - Ausländer, weiblich(2016)
# Einwohner (HW) - Deutsche(2016)                                                          94
# Einwohner (HW) - Deutsche, männlich(2016)                                                94
# ...                                                                                     ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...                                       91
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...                                       86
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...                                       89
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...                                       95
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...                                       94
# Wohnberechtigte Bevölkerung männlich(2016)                                               94
# Wohnberechtigte Bevölkerung weiblich(2016)                                               95
# Wohnfläche(2016)                                                                         94
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)                                               80
# Wohngebäude mit 6 bis 10 Wohnungen(2016)                                                 86
# Wohnungen insgesamt(2016)                                                                95
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)                                                             84
# Wohnungen mit 3 Räumen(2016)                                                             85
# Wohnungen mit 4 Räumen(2016)                                                             95
# Wohnungen mit 5 Räumen(2016)                                                             94
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n                                                                                        95
# ng                                                                                       89
# nu                                                                                       89
# nw                                                                                       89
# sonstige Fläche(2016)
# πRATEN
#
#                                                    Alleinerziehende Männer mit 2 Kindern(2016)  \
# AFD                                                                                         82
# ARNE                                                                                        87
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)                                                    82
# Alleinerziehende Frauen mit 2 Kindern(2016)                                                 80
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...
# Alleinerziehende Männer mit 1 Kind(2016)
# Alleinerziehende Männer mit 2 Kindern(2016)                                                100
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)
# Arbeitslose - 55 Jahre und älter(2016)
# Arbeitslose - Ausländer(2016)
# Arbeitslose - Deutsche(2016)
# Arbeitslose - Frauen(2016)
# Arbeitslose - Männer(2016)
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)
# Betriebsfläche(2016)
# CDU                                                                                         90
# Einpersonenhaushalte(2016)
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)
# Einpersonenhaushalte, weiblich(2016)                                                        81
# Einwohner (HW) - Ausländer(2016)
# Einwohner (HW) - Ausländer, männlich(2016)
# Einwohner (HW) - Ausländer, weiblich(2016)
# Einwohner (HW) - Deutsche(2016)                                                             86
# Einwohner (HW) - Deutsche, männlich(2016)                                                   85
# ...                                                                                        ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...                                          88
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...                                          87
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...                                          80
# Wohnberechtigte Bevölkerung männlich(2016)                                                  84
# Wohnberechtigte Bevölkerung weiblich(2016)                                                  85
# Wohnfläche(2016)                                                                            85
# Wohngebäude insgesamt(2016)                                                                 81
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)                                                  82
# Wohngebäude mit 6 bis 10 Wohnungen(2016)                                                    81
# Wohnungen insgesamt(2016)                                                                   82
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)                                                                87
# Wohnungen mit 4 Räumen(2016)                                                                81
# Wohnungen mit 5 Räumen(2016)                                                                81
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n                                                                                           88
# ng                                                                                          91
# nu
# nw                                                                                          91
# sonstige Fläche(2016)
# πRATEN                                                                                      83
#
#                                                    Alleinerziehende Männer mit 3 oder mehr  Kindern(2016)  \
# AFD
# ARNE
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)
# Alleinerziehende Frauen mit 2 Kindern(2016)
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...
# Alleinerziehende Männer mit 1 Kind(2016)
# Alleinerziehende Männer mit 2 Kindern(2016)
# Alleinerziehende Männer mit 3 oder mehr  Kinder...                                                100
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)
# Arbeitslose - 55 Jahre und älter(2016)
# Arbeitslose - Ausländer(2016)
# Arbeitslose - Deutsche(2016)
# Arbeitslose - Frauen(2016)
# Arbeitslose - Männer(2016)
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)
# Betriebsfläche(2016)
# CDU
# Einpersonenhaushalte(2016)
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)
# Einpersonenhaushalte, weiblich(2016)
# Einwohner (HW) - Ausländer(2016)
# Einwohner (HW) - Ausländer, männlich(2016)
# Einwohner (HW) - Ausländer, weiblich(2016)
# Einwohner (HW) - Deutsche(2016)
# Einwohner (HW) - Deutsche, männlich(2016)
# ...                                                                                               ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...
# Wohnberechtigte Bevölkerung männlich(2016)
# Wohnberechtigte Bevölkerung weiblich(2016)
# Wohnfläche(2016)
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)
# Wohngebäude mit 6 bis 10 Wohnungen(2016)
# Wohnungen insgesamt(2016)
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)
# Wohnungen mit 4 Räumen(2016)
# Wohnungen mit 5 Räumen(2016)
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n
# ng
# nu
# nw
# sonstige Fläche(2016)
# πRATEN
#
#                                                    Arbeitslose - 20 bis unter 25 Jahre alt(2016)  \
# AFD                                                                                           86
# ARNE
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)                                                      91
# Alleinerziehende Frauen mit 2 Kindern(2016)                                                   90
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...                                            90
# Alleinerziehende Männer mit 1 Kind(2016)                                                      88
# Alleinerziehende Männer mit 2 Kindern(2016)
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)                                                100
# Arbeitslose - 55 Jahre und älter(2016)                                                        91
# Arbeitslose - Ausländer(2016)                                                                 90
# Arbeitslose - Deutsche(2016)                                                                  95
# Arbeitslose - Frauen(2016)                                                                    96
# Arbeitslose - Männer(2016)                                                                    97
# Arbeitslose - unter 20 Jahre alt(2016)                                                        87
# Arbeitslose insgesamt(2016)                                                                   97
# Betriebsfläche(2016)
# CDU
# Einpersonenhaushalte(2016)                                                                    85
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...                                            82
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)                                                 90
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)                                                          83
# Einpersonenhaushalte, weiblich(2016)                                                          86
# Einwohner (HW) - Ausländer(2016)                                                              86
# Einwohner (HW) - Ausländer, männlich(2016)                                                    87
# Einwohner (HW) - Ausländer, weiblich(2016)                                                    85
# Einwohner (HW) - Deutsche(2016)                                                               84
# Einwohner (HW) - Deutsche, männlich(2016)                                                     83
# ...                                                                                          ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...                                            82
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...                                            82
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...                                            85
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...                                            87
# Wohnberechtigte Bevölkerung männlich(2016)                                                    86
# Wohnberechtigte Bevölkerung weiblich(2016)                                                    86
# Wohnfläche(2016)                                                                              84
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)
# Wohngebäude mit 6 bis 10 Wohnungen(2016)
# Wohnungen insgesamt(2016)                                                                     88
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)                                                                  88
# Wohnungen mit 3 Räumen(2016)
# Wohnungen mit 4 Räumen(2016)                                                                  92
# Wohnungen mit 5 Räumen(2016)                                                                  86
# Wohnungen mit 6 Räumen(2016)
# ...
# Einwohner (HW) - Deutsche, männlich(2016)
# ...                                                                                  ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...
# Wohnberechtigte Bevölkerung männlich(2016)
# Wohnberechtigte Bevölkerung weiblich(2016)
# Wohnfläche(2016)
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)
# Wohngebäude mit 6 bis 10 Wohnungen(2016)
# Wohnungen insgesamt(2016)
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)
# Wohnungen mit 4 Räumen(2016)
# Wohnungen mit 5 Räumen(2016)
# Wohnungen mit 6 Räumen(2016)                                                          91
# Wohnungen mit 7 und mehr Räumen(2016)                                                100
# n
# ng
# nu
# nw
# sonstige Fläche(2016)
# πRATEN
#
#                                                       n   ng   nu   nw  \
# AFD                                                  93   87   89   87
# ARNE                                                 92   93   86   93
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)             94   88   86   88
# Alleinerziehende Frauen mit 2 Kindern(2016)          93   87   90   87
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...
# Alleinerziehende Männer mit 1 Kind(2016)             95   89   89   89
# Alleinerziehende Männer mit 2 Kindern(2016)          88   91        91
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)        83        81
# Arbeitslose - 55 Jahre und älter(2016)
# Arbeitslose - Ausländer(2016)
# Arbeitslose - Deutsche(2016)                         88        84
# Arbeitslose - Frauen(2016)                           83        82
# Arbeitslose - Männer(2016)                           86        82
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)                          86        83
# Betriebsfläche(2016)
# CDU                                                  98   99   89   99
# Einpersonenhaushalte(2016)                           95   92   86   92
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...   94   92   82   92
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)        89   81   88   81
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)     87   86        86
# Einpersonenhaushalte, männlich(2016)                 94   91   84   91
# Einpersonenhaushalte, weiblich(2016)                 96   92   87   92
# Einwohner (HW) - Ausländer(2016)
# Einwohner (HW) - Ausländer, männlich(2016)
# Einwohner (HW) - Ausländer, weiblich(2016)
# Einwohner (HW) - Deutsche(2016)                      98   96   88   96
# Einwohner (HW) - Deutsche, männlich(2016)            98   96   87   96
# ...                                                 ...  ...  ...  ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...   97   96   85   96
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...   93   90   83   90
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...   96   97   82   97
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...   92   88   83   88
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...   91   86   90   86
# Wohnberechtigte Bevölkerung männlich(2016)           97   95   88   95
# Wohnberechtigte Bevölkerung weiblich(2016)           98   95   89   95
# Wohnfläche(2016)                                     98   96   87   96
# Wohngebäude insgesamt(2016)                               84        84
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)           90   93        93
# Wohngebäude mit 6 bis 10 Wohnungen(2016)             90   90   86   91
# Wohnungen insgesamt(2016)                            97   93   89   93
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)                         93   93   84   93
# Wohnungen mit 4 Räumen(2016)                         95   89   89   89
# Wohnungen mit 5 Räumen(2016)                         95   92   86   92
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n                                                   100   98   90   98
# ng                                                   98  100   86   99
# nu                                                   90   86  100   86
# nw                                                   98   99   86  100
# sonstige Fläche(2016)
# πRATEN                                               90   95        95
#
#                                                    sonstige Fläche(2016)  \
# AFD
# ARNE
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)
# Alleinerziehende Frauen mit 2 Kindern(2016)
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...
# Alleinerziehende Männer mit 1 Kind(2016)
# Alleinerziehende Männer mit 2 Kindern(2016)
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)
# Arbeitslose - 55 Jahre und älter(2016)
# Arbeitslose - Ausländer(2016)
# Arbeitslose - Deutsche(2016)
# Arbeitslose - Frauen(2016)
# Arbeitslose - Männer(2016)
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)
# Betriebsfläche(2016)
# CDU
# Einpersonenhaushalte(2016)
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)
# Einpersonenhaushalte, männlich(2016)
# Einpersonenhaushalte, weiblich(2016)
# Einwohner (HW) - Ausländer(2016)
# Einwohner (HW) - Ausländer, männlich(2016)
# Einwohner (HW) - Ausländer, weiblich(2016)
# Einwohner (HW) - Deutsche(2016)
# Einwohner (HW) - Deutsche, männlich(2016)
# ...                                                                  ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...
# Wohnberechtigte Bevölkerung männlich(2016)
# Wohnberechtigte Bevölkerung weiblich(2016)
# Wohnfläche(2016)
# Wohngebäude insgesamt(2016)
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)
# Wohngebäude mit 3 und mehr Wohnungen(2016)
# Wohngebäude mit 6 bis 10 Wohnungen(2016)
# Wohnungen insgesamt(2016)
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)
# Wohnungen mit 4 Räumen(2016)
# Wohnungen mit 5 Räumen(2016)
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n
# ng
# nu
# nw
# sonstige Fläche(2016)                                                100
# πRATEN
#
#                                                    πRATEN
# AFD
# ARNE                                                   85
# Ackerland(2016)
# Alleinerziehende Frauen mit 1 Kind(2016)
# Alleinerziehende Frauen mit 2 Kindern(2016)
# Alleinerziehende Frauen mit 3 oder mehr  Kinder...
# Alleinerziehende Männer mit 1 Kind(2016)
# Alleinerziehende Männer mit 2 Kindern(2016)            83
# Alleinerziehende Männer mit 3 oder mehr  Kinder...
# Arbeitslose - 20 bis unter 25 Jahre alt(2016)
# Arbeitslose - 55 Jahre und älter(2016)
# Arbeitslose - Ausländer(2016)
# Arbeitslose - Deutsche(2016)
# Arbeitslose - Frauen(2016)
# Arbeitslose - Männer(2016)
# Arbeitslose - unter 20 Jahre alt(2016)
# Arbeitslose insgesamt(2016)
# Betriebsfläche(2016)
# CDU                                                    93
# Einpersonenhaushalte(2016)                             86
# Einpersonenhaushalte, Alter 30 bis unter 60 Jah...     87
# Einpersonenhaushalte, Alter ab 60 Jahre(2016)
# Einpersonenhaushalte, Alter unter 30 Jahre(2016)       88
# Einpersonenhaushalte, männlich(2016)                   86
# Einpersonenhaushalte, weiblich(2016)                   86
# Einwohner (HW) - Ausländer(2016)
# Einwohner (HW) - Ausländer, männlich(2016)
# Einwohner (HW) - Ausländer, weiblich(2016)
# Einwohner (HW) - Deutsche(2016)                        89
# Einwohner (HW) - Deutsche, männlich(2016)              89
# ...                                                   ...
# Wohnberechtigte Bevölkerung 0 bis unter 18 Jahr...     91
# Wohnberechtigte Bevölkerung 18 bis unter 35 Jah...     87
# Wohnberechtigte Bevölkerung 35 bis unter 50 Jah...     94
# Wohnberechtigte Bevölkerung 50 bis unter 65 Jah...
# Wohnberechtigte Bevölkerung 65 Jahre und darübe...
# Wohnberechtigte Bevölkerung männlich(2016)             88
# Wohnberechtigte Bevölkerung weiblich(2016)             87
# Wohnfläche(2016)                                       89
# Wohngebäude insgesamt(2016)                            84
# Wohngebäude mit 1 Wohnung(2016)
# Wohngebäude mit 11 bis 20 Wohnungen(2016)
# Wohngebäude mit 2 Wohnungen(2016)
# Wohngebäude mit 21 und mehr Wohnungen(2016)
# Wohngebäude mit 3 bis 5 Wohnungen(2016)                84
# Wohngebäude mit 3 und mehr Wohnungen(2016)             94
# Wohngebäude mit 6 bis 10 Wohnungen(2016)               86
# Wohnungen insgesamt(2016)                              84
# Wohnungen mit 1 Raum(2016)
# Wohnungen mit 2 Räumen(2016)
# Wohnungen mit 3 Räumen(2016)                           89
# Wohnungen mit 4 Räumen(2016)
# Wohnungen mit 5 Räumen(2016)                           82
# Wohnungen mit 6 Räumen(2016)
# Wohnungen mit 7 und mehr Räumen(2016)
# n                                                      90
# ng                                                     95
# nu
# nw                                                     95
# sonstige Fläche(2016)
# πRATEN                                                100
#
# [177 rows x 177 columns]

# %%
s = bm1["n"]
s.clip(1000)
# Out:
# Bezirk
# 001 Dezernat Stadtentwicklung                                 1685
# 002 WE Catering / Raum OG                                     1144
# 003 Nordschule / Raum 00_03                                   1000
# 004 WE Catering / Raum EG                                     1682
# 005 Volksbad-Anbau                                            1543
# 006 Seniorenwohnen Am Villengang                              1000
# 007 Technologie- und Innovationspark Jena                     1270
# 008 Feuerwehrgerätehaus Lichtenhain                           1000
# 009 Jenaplan-Schule / Raum 01.00.15                           1000
# 010 Jenaplan-Schule / Raum 01.00.14                           1532
# 011 Jenaplan-Schule / Raum 01.00.13                           1374
# 012 Aktion Wandlungswelten / EG Zimmer 2                      1000
# 013 Aktion Wandlungswelten / EG Zimmer 3                      1022
# 014 IGS Grete Unrein / Raum 00-14                             1397
# 015 IGS Grete Unrein / Raum 00-15                             1598
# 016 Kita Leutragarten                                         1245
# 017 Ortsteilbüro Jena-West                                    1404
# 018 FSU Jena  Helmholtzweg 4                                  1000
# 019 Nordschule / Raum 00_04                                   1000
# 020 Nordschule / Raum 00_05                                   1260
# 021 Montessorischule Jena / Aula Raum 02-00-01                1305
# 022 Carl-Zeiss-Gymnasium  / Raum D 112                        1000
# 023 Christliches Gymnasium / EG Raum 012                      1000
# 024 Begegnungszentrum Jena e.V. / Seniorenbegegnungsstätte    1000
# 025 Begegnungszentrum Jena e.V. / Bibliothek                  1000
# 026 Montessorischule Jena / kleiner Speiseraum 02-00-16       1351
# 027 Carl-Zeiss-Gymnasium  / Raum D 114                        1060
# 028 Christliches Gymnasium / EG Raum 004                      1592
# 029 K&B Verkehrs-Bildungs-Gesellschaft / Raum 1               1094
# 030 K&B Verkehrs-Bildungs-Gesellschaft / Raum 2               1309
#                                                               ...
# 058 Lobdeburgschule                                           1379
# 059 Ganztagsgrundschule SteinMalEins                          1655
# 060 Gaststätte Schöne Aussicht                                1000
# 061 SBS für Gesundheit u. Soziales                            1536
# 062 Seniorenzentrum Käthe Kollwitz / Andachtsraum             1000
# 063 Seniorenzentrum Käthe Kollwitz / Konferenzraum            1031
# 064 Wohnen am Apfeldorn / Foyer hinterer Bereich              1000
# 065 Wohnen am Apfeldorn / Foyer rechts Büro Hausmeister       1000
# 066 Seniorenbegegnungszentrum Ernst-Schneller-Str. 10         1000
# 067 Wohnpark Lebenszeit                                       1054
# 068 Begegnungsstätte Alt und Jung                             1018
# 069 Schillerschule  / Anbau großer Raum                       1000
# 070 Gemeinschaftsschule An der Trießnitz                      1000
# 071 Ortsteilrat Winzerla                                      1000
# 072 Schillerschule / Musikraum 00_03.01                       1304
# 073 Seniorenheim Am Kleinertal                                1000
# 074 Schillerschule / Aula                                     1337
# 075 Alte Schule Kunitz                                        1000
# 076 Gemeindesaal Jenaprießnitz                                1000
# 077 Gemeindesaal Drackendorf                                  1000
# 078 Heimatverein Ilmnitz                                      1000
# 079 Gaststätte Goldenes Schiff                                1000
# 080 Feuerwehrgerätehaus Leutra                                1000
# 081 Feuerwehrvereinshaus Münchenroda                          1000
# 082 Gemeindebüro Isserstedt                                   1000
# 083 Feuerwehrgerätehaus Vierzehnheiligen                      1000
# 084 Feuerwehrgerätehaus Krippendorf                           1000
# 085 Vereinshaus Lützeroda                                     1000
# 086 Gemeindebüro Cospeda                                      1128
# 087 Feuerwehrgerätehaus Closewitz                             1000
# Name: n, Length: 87, dtype: int64
